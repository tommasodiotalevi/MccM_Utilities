# %%
import pandas as pd
import numpy as np
import requests
import re
import csv

# %% [markdown]
# ### MSSM production

# %%
params_bbA = (
(130, 130.0, 0.010493000038, 34.67, 2),
(130, 130.0, 0.0632193982601, 34.67, 5),
(130, 130.0, 0.24627700448, 34.67, 10),
(130, 130.0, 0.539524018764, 34.67, 15),
(130, 130.0, 0.934086978436, 34.67, 20),
(130, 130.0, 1.42189002037, 34.67, 25),
(130, 130.0, 1.99556994438, 34.67, 30),
(130, 130.0, 3.37421989441, 34.67, 40),
(130, 130.0, 5.02288007736, 34.67, 50),
(130, 130.0, 6.90216016769, 34.67, 60),
(150, 150.0, 0.0119343996048, 39.67, 2),
(150, 150.0, 0.0711368992925, 39.67, 5),
(150, 150.0, 0.277087986469, 39.67, 10),
(150, 150.0, 0.607074022293, 39.67, 15),
(150, 150.0, 1.05113005638, 39.67, 20),
(150, 150.0, 1.60020005703, 39.67, 25),
(150, 150.0, 2.24601006508, 39.67, 30),
(150, 150.0, 3.79836010933, 39.67, 40),
(150, 150.0, 5.65531015396, 39.67, 50),
(150, 150.0, 7.77265977859, 39.67, 60),
(170, 170.0, 0.0755437985063, 44.67, 2),
(170, 170.0, 0.0960299000144, 44.67, 5),
(170, 170.0, 0.307368010283, 44.67, 10),
(170, 170.0, 0.673457026482, 44.67, 15),
(170, 170.0, 1.16615998745, 44.67, 20),
(170, 170.0, 1.77543997765, 44.67, 25),
(170, 170.0, 2.49217009544, 44.67, 30),
(170, 170.0, 4.21531009674, 44.67, 40),
(170, 170.0, 6.27710008621, 44.67, 50),
(170, 170.0, 8.62866973877, 44.67, 60),
(200, 200.0, 0.125039994717, 52.17, 2),
(200, 200.0, 0.145147994161, 52.17, 5),
(200, 200.0, 0.389194995165, 52.17, 10),
(200, 200.0, 0.802561998367, 52.17, 15),
(200, 200.0, 1.36338996887, 52.17, 20),
(200, 200.0, 2.05859994888, 52.17, 25),
(200, 200.0, 2.87725996971, 52.17, 30),
(200, 200.0, 4.84704017639, 52.17, 40),
(200, 200.0, 7.20547008514, 52.17, 50),
(200, 200.0, 9.8966999054, 52.17, 60),
(250, 250.0, 0.349893003702, 64.67, 2),
(250, 250.0, 0.311803013086, 64.67, 5),
(250, 250.0, 0.571631014347, 64.67, 10),
(250, 250.0, 1.05692005157, 64.67, 15),
(250, 250.0, 1.72554004192, 64.67, 20),
(250, 250.0, 2.55837988853, 64.67, 25),
(250, 250.0, 3.5411798954, 64.67, 30),
(250, 250.0, 5.90956020355, 64.67, 40),
(250, 250.0, 8.7484703064, 64.67, 50),
(250, 250.0, 11.9905004501, 64.67, 60),
(300, 300.0, 1.22206997871, 77.17, 2),
(300, 300.0, 0.945649027824, 77.17, 5),
(300, 300.0, 1.08016002178, 77.17, 10),
(300, 300.0, 1.56194996834, 77.17, 15),
(300, 300.0, 2.29893994331, 77.17, 20),
(300, 300.0, 3.23931002617, 77.17, 25),
(300, 300.0, 4.361120224, 77.17, 30),
(300, 300.0, 7.08514022827, 77.17, 40),
(300, 300.0, 10.3650999069, 77.17, 50),
(700, 699.21697998, 35.1092987061, 176.974244995, 60),
(800, 804.077026367, 17.6781997681, 203.189256592, 2),
(800, 800.846008301, 10.3087997437, 202.381502075, 5),
(800, 800.15802002, 9.88471984863, 202.209505005, 10),
(800, 800.007995605, 10.9596996307, 202.171998901, 15),
(800, 799.935974121, 12.6674003601, 202.15399353, 20),
(800, 799.880004883, 14.8605003357, 202.140001221, 25),
(800, 799.822021484, 17.4771003723, 202.125505371, 30),
(800, 799.671020508, 23.8293991089, 202.087755127, 40),
(800, 799.437988281, 31.4869003296, 202.02949707, 50),
(800, 799.07800293, 40.2708015442, 201.939500732, 60),
(1000, 1002.84002686, 23.1996002197, 252.880006714, 2),
(1000, 1000.58001709, 13.8654003143, 252.315004272, 5),
(1000, 1000.07000732, 13.3586997986, 252.187501831, 10),
(1000, 999.945007324, 14.6746997833, 252.156251831, 15),
(1000, 999.87902832, 16.7516002655, 252.13975708, 20),
(1000, 999.818969727, 19.4132995605, 252.124742432, 25),
(1000, 999.75, 22.5867996216, 252.1075, 30),
(1000, 999.562011719, 30.2896003723, 252.06050293, 40),
(1000, 999.265991211, 39.5791015625, 251.986497803, 50),
(1000, 998.807006836, 50.2439002991, 251.871751709, 60),
(1200, 1202.01000977, 28.3960990906, 302.672502441, 2),
(1200, 1200.39001465, 17.2569007874, 302.267503662, 5),
(1200, 1199.98999023, 16.6774997711, 302.167497559, 10),
(1200, 1199.89001465, 18.2266998291, 302.142503662, 15),
(1200, 1199.82995605, 20.6601009369, 302.127489014, 20),
(1200, 1199.76000977, 23.7745990753, 302.110002441, 25),
(1200, 1199.68005371, 27.4860992432, 302.090013428, 30),
(1200, 1199.45996094, 36.4943008423, 302.034990234, 40),
(1200, 1199.09997559, 47.3611984253, 301.944993896, 50),
(1200, 1198.54003906, 59.8446006775, 301.805009766, 60),
(1500, 1501.07995605, 35.8452987671, 377.439989014, 2),
(1500, 1500.17004395, 22.1681995392, 377.212510986, 5),
(1500, 1499.90002441, 21.4839000702, 377.145006104, 10),
(1500, 1499.81994629, 23.3654003143, 377.124986572, 15),
(1500, 1499.75, 26.3083000183, 377.1075, 20),
(1500, 1499.67004395, 30.0701007843, 377.087510986, 25),
(1500, 1499.57995605, 34.5508995056, 377.064989014, 30),
(1500, 1499.30004883, 45.4239997864, 376.995012207, 40),
(1500, 1498.84997559, 58.5424995422, 376.882493896, 50),
(1500, 1498.15002441, 73.619102478, 376.707506104, 60),
)

# %%
pythia_fragment_CUEP8M1 = """
from Configuration.Generator.Pythia8CommonSettings_cfi import *
from Configuration.Generator.Pythia8CUEP8M1Settings_cfi import *
from Configuration.Generator.Pythia8PowhegEmissionVetoSettings_cfi import *
from Configuration.Generator.Pythia8aMCatNLOSettings_cfi import *

generator = cms.EDFilter("Pythia8HadronizerFilter",
                         maxEventsToPrint = cms.untracked.int32(1),
                         pythiaPylistVerbosity = cms.untracked.int32(1),
                         filterEfficiency = cms.untracked.double(1.0),
                         pythiaHepMCVerbosity = cms.untracked.bool(False),
                         comEnergy = cms.double(13000.),
                         PythiaParameters = cms.PSet(
                            pythia8CommonSettingsBlock,
                            pythia8CUEP8M1SettingsBlock,
                            pythia8aMCatNLOSettingsBlock,
                            processParameters = cms.vstring(
                                __CHANNEL_DECAY_FRAGMENT__
                                ),
                            parameterSets = cms.vstring('pythia8CommonSettings',
                                    'pythia8CUEP8M1Settings',
                                    'pythia8aMCatNLOSettings',
                                    'processParameters',
                                    )
                            )
                         )
                         
ProductionFilterSequence = cms.Sequence(generator)
"""

# %%
def fragmentsDictCreator (decay_fr):
    dict = { '2016': pythia_fragment_CUEP8M1.replace('__CHANNEL_DECAY_FRAGMENT__',decay_fr),
             '2016APV': pythia_fragment_CUEP8M1.replace('__CHANNEL_DECAY_FRAGMENT__',decay_fr),
             '2017': pythia_fragment_CUEP8M1.replace('__CHANNEL_DECAY_FRAGMENT__',decay_fr),
             '2018': pythia_fragment_CUEP8M1.replace('__CHANNEL_DECAY_FRAGMENT__',decay_fr)
                    }
    return dict

# %%
LHEproducer = """
import FWCore.ParameterSet.Config as cms

# link to cards:
# __EXAMPLE__

externalLHEProducer = cms.EDProducer("ExternalLHEProducer",
    args = cms.vstring('__GRIDPACK__'),
    nEvents = cms.untracked.uint32(5000),
    numberOfParameters = cms.uint32(1),
    outputFile = cms.string('cmsgrid_final.lhe'),
    scriptName = cms.FileInPath('GeneratorInterface/LHEInterface/data/run_generic_tarball_cvmfs.sh')
)
"""

# %%
years = ["2016", "2016APV", "2017", "2018"]
processes = ["BBH","BBA","BBh"]
#mass_point = ["130","150","170","190","200","250","300","350","400","450","500","600","700","800","1000","1200","1500"]
tot_events = 10000
gridpacks_dict = {}
example_dict = {}
dataset_names = {}

# %%
for year in range(len(years)):
    t_example1 = 'https://github.com/cms-sw/genproductions/tree/master/bin/Powheg/production/2017/13TeV/Higgs/MSSM/bbH_MuMu_NNPDF31_13TeV'
    t_example2 = 'https://github.com/cms-sw/genproductions/tree/master/bin/Powheg/production/2017/13TeV/Higgs/MSSM/bbA_MuMu_NNPDF31_13TeV'
    t_example3 = 'https://github.com/cms-sw/genproductions/tree/master/bin/Powheg/production/2017/13TeV/Higgs/MSSM/bbh_MuMu_NNPDF31_13TeV'
    t_datasetname_year = 'MSSMGluGluTo{process}ToMuMu_MA-{M}_Tanb-{tanb}_TuneCUETP8M1_13TeV-powheg-pythia8'
    t_gp_year = "/cvmfs/cms.cern.ch/phys_generator/gridpacks/UL/13TeV/powheg/V2/slc7_amd64_gcc700_CMSSW_10_6_19_MSSMGluGluTo{process}ToMuMu_ma{M}_tb{tanb}/v1/slc7_amd64_gcc700_CMSSW_10_6_19_MSSMGluGluTo{process}ToMuMu_ma{M}_tb{tanb}.tgz"    
    tmp_dataset_dict={}
    tmp_gridpack_dict={}
    tmp_example_dict={}
    dataset_names_year = []
    gp_ggf_year = "gp_ggf_" + years[year]
    gp_ggf_year = []

    for process in range(len(processes)):
        #gp_ggf_year = "gp_ggf_" + years[year]
        dataset_names_year = []
        gp_ggf_year = []

        if processes[process] == "BBH":
            for M, mass, width, hdamp, tanb in params_bbH: 
                d = {"process":processes[process], "M": M, "tanb": tanb}
                tmp_example_dict[processes[process]] = t_example1
                gp_ggf_year.append(t_gp_year.format_map(d))
                dataset_names_year.append(t_datasetname_year.format_map(d))
                tmp_dataset_dict[processes[process]] = dataset_names_year
                tmp_gridpack_dict[processes[process]] = gp_ggf_year
        elif processes[process] == "BBA":
            for M, mass, width, hdamp, tanb in params_bbA: 
                d = {"process":processes[process], "M": M, "tanb": tanb}
                tmp_example_dict[processes[process]] = t_example2
                gp_ggf_year.append(t_gp_year.format_map(d))
                dataset_names_year.append(t_datasetname_year.format_map(d))
                tmp_dataset_dict[processes[process]] = dataset_names_year
                tmp_gridpack_dict[processes[process]] = gp_ggf_year
        elif processes[process] == "BBh":
            d = {"process":processes[process], "M": 125, "tanb": 30}
            tmp_example_dict[processes[process]] = t_example3
            gp_ggf_year.append(t_gp_year.format_map(d))
            dataset_names_year.append(t_datasetname_year.format_map(d))
            tmp_dataset_dict[processes[process]] = dataset_names_year
            tmp_gridpack_dict[processes[process]] = gp_ggf_year
            
    gridpacks_dict[years[year]] = tmp_gridpack_dict
    dataset_names[years[year]] = tmp_dataset_dict
    example_dict[years[year]] = tmp_example_dict

#print(gridpacks_dict['2016']['bbH'])
#gridpacks_dict = {'VBF_HH' : {'2016': gp_vbf_2016, '2017': gp_vbf_2017, '2018': gp_vbf_2018}}                                                                                                              
#for x in gridpacks_dict:                                                                                                                                                                                   
#    print (x)                                                                                                                                                                                              
#    for y in gridpacks_dict[x]:                                                                                                                                                                            
#        print (y,':', gridpacks_dict[x][y])

# %%
bb_mumu = '''                                                                                                                                                                                           
    'TimeShower:nPartonsInBorn = 2', #number of coloured particles (before resonance decays) in born matrix element
    'SLHA:useDecayTable = off',
    '25:m0 = __HIGGS_MASS__',
    '25:mWidth = __HIGGS_WIDTH__',
    '25:onMode = off',
    '25:onIfMatch = 13 -13',
'''
#'SpaceShower:dipoleRecoil = on'

# %% [markdown]
# ## .csv Production

# %%
#MadgraphVersion = re.compile("V5_2\.[0-9]\.[0-9]")
process_pythia_map = {}
tmp_process_pythia_map = {}
for process in processes:
    tmp_process_pythia_map[process] = fragmentsDictCreator(bb_mumu)
process_pythia_map.update(tmp_process_pythia_map)

# %%
#for year in range(len(years)):
for year in gridpacks_dict:
    #print(year)
    for process in processes:
        if process == "BBH":
            with open('bb_'+ process +'_'+year+'.csv', 'w') as csvfile:
                csvwriter = csv.writer(csvfile, delimiter=',',
                            quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csvwriter.writerow(['Dataset name','Events', 'fragment','notes','Generator','mcdbid','time','size'])
                i=0
                for M, mass, width, hdamp, tanb in params_bbH:
                    tmp_fragment=""
                    #print(gridpacks_dict[year][i])
                    #print(dataset_names[year][i])
                    #version = MadgraphVersion.search(path).group(0)
                    version="V2"
                    dataset_name = dataset_names[year][process][i]
                    if year == "2016APV":
                        events = round(tot_events*0.54)
                    elif year == "2016":
                        events = round(tot_events*0.46)
                    else:
                        events = tot_events
                    tmp_fragment = LHEproducer.replace('__GRIDPACK__',gridpacks_dict[year][process][i]) + '\n' + process_pythia_map[process][year]
                    final_fragment = tmp_fragment.replace('__EXAMPLE__',example_dict[year][process])
                    final_fragment = final_fragment.replace('__HIGGS_MASS__', str(mass))
                    final_fragment = final_fragment.replace('__HIGGS_WIDTH__', str(width))
                    note = dataset_name.replace('_',' ')
                    generators="Powheg_" + version + "  Pythia8"
                    mcdb_id = '0'
                    time = '15'
                    size = '105'
                    csvwriter.writerow([dataset_name, events, final_fragment, note, generators, mcdb_id, time, size])
                    i=i+1
                csvfile.close()
        elif process == "BBA":
            with open('bb_'+ process +'_'+year+'.csv', 'w') as csvfile:
                csvwriter = csv.writer(csvfile, delimiter=',',
                            quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csvwriter.writerow(['Dataset name','Events', 'fragment','notes','Generator','mcdbid','time','size'])
                i=0       
                for M, mass, width, hdamp, tanb in params_bbA:
                    tmp_fragment=""
                    #print(gridpacks_dict[year][i])
                    #print(dataset_names[year][i])
                    #version = MadgraphVersion.search(path).group(0)
                    version="V2"
                    dataset_name = dataset_names[year][process][i]
                    if year == "2016APV":
                        events = round(tot_events*0.54)
                    elif year == "2016":
                        events = round(tot_events*0.46)
                    else:
                        events = tot_events
                    tmp_fragment = LHEproducer.replace('__GRIDPACK__',gridpacks_dict[year][process][i]) + '\n' + process_pythia_map[process][year]
                    final_fragment = tmp_fragment.replace('__EXAMPLE__',example_dict[year][process])
                    final_fragment = final_fragment.replace('__HIGGS_MASS__', str(mass))
                    final_fragment = final_fragment.replace('__HIGGS_WIDTH__', str(width))
                    note = dataset_name.replace('_',' ')
                    generators="Powheg_" + version + "  Pythia8"
                    mcdb_id = '0'
                    time = '15'
                    size = '105'
                    csvwriter.writerow([dataset_name, events, final_fragment, note, generators, mcdb_id, time, size])
                    i=i+1
                csvfile.close()
                    
        elif process == "BBh":
            with open('bb_'+ "BBx" +'_'+year+'.csv', 'w') as csvfile:
                csvwriter = csv.writer(csvfile, delimiter=',',
                            quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csvwriter.writerow(['Dataset name','Events', 'fragment','notes','Generator','mcdbid','time','size'])
                i=0            
                tmp_fragment=""
                version="V2"
                dataset_name = dataset_names[year][process][i]
                if year == "2016APV":
                    events = round(tot_events*0.54)
                elif year == "2016":
                    events = round(tot_events*0.46)
                else:
                    events = tot_events
                tmp_fragment = LHEproducer.replace('__GRIDPACK__',gridpacks_dict[year][process][i]) + '\n' + process_pythia_map[process][year]
                final_fragment = tmp_fragment.replace('__EXAMPLE__',example_dict[year][process])
                final_fragment = final_fragment.replace('__HIGGS_MASS__', str(121.861000061))
                final_fragment = final_fragment.replace('__HIGGS_WIDTH__', str(1.03110003471))
                note = dataset_name.replace('_',' ')
                generators="Powheg_" + version + "  Pythia8"
                mcdb_id = '0'
                time = '0.001'
                size = '30'
                csvwriter.writerow([dataset_name, events, final_fragment, note, generators, mcdb_id, time, size])
                csvfile.close()
