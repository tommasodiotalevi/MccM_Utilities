# %%
import pandas as pd
import numpy as np
import requests
import re
import csv

# %% [markdown]
# ### MSSM production

# %%
params_ggA = (
(130, 2),
(130, 5),
(130, 10),
(130, 15),
(130, 20),
(130, 25),
(130, 30),
(130, 40),
(130, 50),
(130, 60),
(150, 2),
(150, 5),
(150, 10),
(150, 15),
(150, 20),
(150, 25),
(150, 30),
(150, 40),
(150, 50),
(150, 60),
(170, 2),
(170, 5),
(170, 10),
(170, 15),
(170, 20),
(170, 25),
(170, 30),
(170, 40),
(170, 50),
(170, 60),
(200, 2),
(200, 5),
(200, 10),
(200, 15),
(200, 20),
(200, 25),
(200, 30),
(200, 40),
(200, 50),
(200, 60),
(250, 2),
(250, 5),
(250, 10),
(250, 15),
(250, 20),
(250, 25),
(250, 30),
(250, 40),
(250, 50),
(250, 60),
(300, 2),
(300, 5),
(300, 10),
(300, 15),
(300, 20),
(300, 25),
(300, 30),
(300, 40),
(300, 50),
(300, 60),
(350, 2),
(350, 5),
(350, 10),
(350, 15),
(350, 20),
(350, 25),
(350, 30),
(350, 40),
(350, 50),
(350, 60),
(400, 2),
(400, 5),
(400, 10),
(400, 15),
(400, 20),
(400, 25),
(400, 30),
(400, 40),
(400, 50),
(400, 60),
(450, 2),
(450, 5),
(450, 10),
(450, 15),
(450, 20),
(450, 25),
(450, 30),
(450, 40),
(450, 50),
(450, 60),
(500, 2),
(500, 5),
(500, 10),
(500, 15),
(500, 20),
(500, 25),
(500, 30),
(500, 40),
(500, 50),
(500, 60),
(600, 2),
(600, 5),
(600, 10),
(600, 15),
(600, 20),
(600, 25),
(600, 30),
(600, 40),
(600, 50),
(600, 60),
(700, 2),
(700, 5),
(700, 10),
(700, 15),
(700, 20),
(700, 25),
(700, 30),
(700, 40),
(700, 50),
(700, 60),
(800, 2),
(800, 5),
(800, 10),
(800, 15),
(800, 20),
(800, 25),
(800, 30),
(800, 40),
(800, 50),
(800, 60),
(1000, 2),
(1000, 5),
(1000, 10),
(1000, 15),
(1000, 20),
(1000, 25),
(1000, 30),
(1000, 40),
(1000, 50),
(1000, 60),
(1200, 2),
(1200, 5),
(1200, 10),
(1200, 15),
(1200, 20),
(1200, 25),
(1200, 30),
(1200, 40),
(1200, 50),
(1200, 60),
(1500, 2),
(1500, 5),
(1500, 10),
(1500, 15),
(1500, 20),
(1500, 25),
(1500, 30),
(1500, 40),
(1500, 50),
(1500, 60),
)

# %%
params_ggH = (
(130, 2),
(130, 5),
(130, 10),
(130, 15),
(130, 20),
(130, 25),
(130, 30),
(130, 40),
(130, 50),
(130, 60),
(150, 2),
(150, 5),
(150, 10),
(150, 15),
(150, 20),
(150, 25),
(150, 30),
(150, 40),
(150, 50),
(150, 60),
(170, 2),
(170, 5),
(170, 10),
(170, 15),
(170, 20),
(170, 25),
(170, 30),
(170, 40),
(170, 50),
(170, 60),
(200, 2),
(200, 5),
(200, 10),
(200, 15),
(200, 20),
(200, 25),
(200, 30),
(200, 40),
(200, 50),
(200, 60),
(250, 2),
(250, 5),
(250, 10),
(250, 15),
(250, 20),
(250, 25),
(250, 30),
(250, 40),
(250, 50),
(250, 60),
(300, 2),
(300, 5),
(300, 10),
(300, 15),
(300, 20),
(300, 25),
(300, 30),
(300, 40),
(300, 50),
(300, 60),
(350, 2),
(350, 5),
(350, 10),
(350, 15),
(350, 20),
(350, 25),
(350, 30),
(350, 40),
(350, 50),
(350, 60),
(400, 2),
(400, 5),
(400, 10),
(400, 15),
(400, 20),
(400, 25),
(400, 30),
(400, 40),
(400, 50),
(400, 60),
(450, 2),
(450, 5),
(450, 10),
(450, 15),
(450, 20),
(450, 25),
(450, 30),
(450, 40),
(450, 50),
(450, 60),
(500, 2),
(500, 5),
(500, 10),
(500, 15),
(500, 20),
(500, 25),
(500, 30),
(500, 40),
(500, 50),
(500, 60),
(600, 2),
(600, 5),
(600, 10),
(600, 15),
(600, 20),
(600, 25),
(600, 30),
(600, 40),
(600, 50),
(600, 60),
(700, 2),
(700, 5),
(700, 10),
(700, 15),
(700, 20),
(700, 25),
(700, 30),
(700, 40),
(700, 50),
(700, 60),
(800, 2),
(800, 5),
(800, 10),
(800, 15),
(800, 20),
(800, 25),
(800, 30),
(800, 40),
(800, 50),
(800, 60),
(1000, 2),
(1000, 5),
(1000, 10),
(1000, 15),
(1000, 20),
(1000, 25),
(1000, 30),
(1000, 40),
(1000, 50),
(1000, 60),
(1200, 2),
(1200, 5),
(1200, 10),
(1200, 15),
(1200, 20),
(1200, 25),
(1200, 30),
(1200, 40),
(1200, 50),
(1200, 60),
(1500, 2),
(1500, 5),
(1500, 10),
(1500, 15),
(1500, 20),
(1500, 25),
(1500, 30),
(1500, 40),
(1500, 50),
(1500, 60),
)

# %%
pythia_fragment_CUEP8M1 = """
from Configuration.Generator.Pythia8CommonSettings_cfi import *
from Configuration.Generator.Pythia8CUEP8M1Settings_cfi import *
from Configuration.Generator.Pythia8PowhegEmissionVetoSettings_cfi import *

generator = cms.EDFilter("Pythia8HadronizerFilter",
                         maxEventsToPrint = cms.untracked.int32(1),
                         pythiaPylistVerbosity = cms.untracked.int32(1),
                         filterEfficiency = cms.untracked.double(1.0),
                         pythiaHepMCVerbosity = cms.untracked.bool(False),
                         comEnergy = cms.double(13000.),
                         PythiaParameters = cms.PSet(
        pythia8CommonSettingsBlock,
        pythia8CUEP8M1SettingsBlock,
        pythia8PowhegEmissionVetoSettingsBlock,
        processParameters = cms.vstring(
            __CHANNEL_DECAY_FRAGMENT__
            ),
        parameterSets = cms.vstring('pythia8CommonSettings',
                                    'pythia8CUEP8M1Settings',
                                    'pythia8PowhegEmissionVetoSettings',
                                    'processParameters'
                                    )
        )
                         )
                         
ProductionFilterSequence = cms.Sequence(generator)
"""

# %%
def fragmentsDictCreator (decay_fr):
    dict = { '2016': pythia_fragment_CUEP8M1.replace('__CHANNEL_DECAY_FRAGMENT__',decay_fr),
             '2016APV': pythia_fragment_CUEP8M1.replace('__CHANNEL_DECAY_FRAGMENT__',decay_fr),
             '2017': pythia_fragment_CUEP8M1.replace('__CHANNEL_DECAY_FRAGMENT__',decay_fr),
             '2018': pythia_fragment_CUEP8M1.replace('__CHANNEL_DECAY_FRAGMENT__',decay_fr)
                    }
    return dict

# %%
LHEproducer = """
import FWCore.ParameterSet.Config as cms

# link to cards:
# __EXAMPLE__

externalLHEProducer = cms.EDProducer("ExternalLHEProducer",
    args = cms.vstring('__GRIDPACK__'),
    nEvents = cms.untracked.uint32(5000),
    numberOfParameters = cms.uint32(1),
    outputFile = cms.string('cmsgrid_final.lhe'),
    scriptName = cms.FileInPath('GeneratorInterface/LHEInterface/data/run_generic_tarball_cvmfs.sh')
)
"""

# %%
years = ["2016", "2016APV", "2017", "2018"]
processes = ["H","A","h"]
#mass_point = ["130","150","170","190","200","250","300","350","400","450","500","600","700","800","1000","1200","1500"]
tot_events = 10000
gridpacks_dict = {}
example_dict = {}
dataset_names = {}

# %%
for year in range(len(years)):
    t_example1 = 'https://github.com/cms-sw/genproductions/tree/master/bin/Powheg/production/2017/13TeV/Higgs/MSSM/ggH_MuMu_NNPDF31_13TeV'
    t_example2 = 'https://github.com/cms-sw/genproductions/tree/master/bin/Powheg/production/2017/13TeV/Higgs/MSSM/ggA_MuMu_NNPDF31_13TeV'
    t_example3 = 'https://github.com/cms-sw/genproductions/tree/master/bin/Powheg/production/2017/13TeV/Higgs/MSSM/ggh_MuMu_NNPDF31_13TeV'
    t_datasetname_year = 'MSSMGluGluTo{process}ToMuMu_MA-{M}_Tanb-{tanb}_TuneCUETP8M1_13TeV-powheg-pythia8'
    t_gp_year = "/cvmfs/cms.cern.ch/phys_generator/gridpacks/UL/13TeV/powheg/V2/slc7_amd64_gcc700_CMSSW_10_6_19_MSSMGluGluTo{process}ToMuMu_ma{M}_tb{tanb}/v1/slc7_amd64_gcc700_CMSSW_10_6_19_MSSMGluGluTo{process}ToMuMu_ma{M}_tb{tanb}.tgz"    
    tmp_dataset_dict={}
    tmp_gridpack_dict={}
    tmp_example_dict={}
    dataset_names_year = []
    gp_ggf_year = "gp_ggf_" + years[year]
    gp_ggf_year = []

    for process in range(len(processes)):
        #gp_ggf_year = "gp_ggf_" + years[year]
        dataset_names_year = []
        gp_ggf_year = []

        if processes[process] == "H":
            for M, tanb in params_ggH: 
                d = {"process":processes[process], "M": M, "tanb": tanb}
                tmp_example_dict[processes[process]] = t_example1
                gp_ggf_year.append(t_gp_year.format_map(d))
                dataset_names_year.append(t_datasetname_year.format_map(d))
                tmp_dataset_dict[processes[process]] = dataset_names_year
                tmp_gridpack_dict[processes[process]] = gp_ggf_year
        elif processes[process] == "A":
            for M, tanb in params_ggA: 
                d = {"process":processes[process], "M": M, "tanb": tanb}
                tmp_example_dict[processes[process]] = t_example2
                gp_ggf_year.append(t_gp_year.format_map(d))
                dataset_names_year.append(t_datasetname_year.format_map(d))
                tmp_dataset_dict[processes[process]] = dataset_names_year
                tmp_gridpack_dict[processes[process]] = gp_ggf_year
        elif processes[process] == "h":
            d = {"process":processes[process], "M": 125, "tanb": 30}
            tmp_example_dict[processes[process]] = t_example2
            gp_ggf_year.append(t_gp_year.format_map(d))
            dataset_names_year.append(t_datasetname_year.format_map(d))
            tmp_dataset_dict[processes[process]] = dataset_names_year
            tmp_gridpack_dict[processes[process]] = gp_ggf_year
                
    gridpacks_dict[years[year]] = tmp_gridpack_dict
    dataset_names[years[year]] = tmp_dataset_dict
    example_dict[years[year]] = tmp_example_dict

#print(gridpacks_dict['2016']['bbH'])
#gridpacks_dict = {'VBF_HH' : {'2016': gp_vbf_2016, '2017': gp_vbf_2017, '2018': gp_vbf_2018}}                                                                                                              
#for x in gridpacks_dict:                                                                                                                                                                                   
#    print (x)                                                                                                                                                                                              
#    for y in gridpacks_dict[x]:                                                                                                                                                                            
#        print (y,':', gridpacks_dict[x][y])

# %%
gg_mumu = '''                                                                                                                                                                                           
    'Higgs:useBSM = on',
    'POWHEG:nFinal = 1',
    '35:onMode = off', # turn OFF all H decays
    '35:onIfMatch = 13 -13', # turn ON H->tautau
'''
#'SpaceShower:dipoleRecoil = on'

# %% [markdown]
# ## .csv Production

# %%
#MadgraphVersion = re.compile("V5_2\.[0-9]\.[0-9]")
process_pythia_map = {}
tmp_process_pythia_map = {}
for process in processes:
    tmp_process_pythia_map[process] = fragmentsDictCreator(gg_mumu)
process_pythia_map.update(tmp_process_pythia_map)

# %%
#for year in range(len(years)):
for year in gridpacks_dict:
    #print(year)
    for process in processes:
        if process == "H":
            with open('ggF_'+process+'_'+year+'.csv', 'w') as csvfile:
                csvwriter = csv.writer(csvfile, delimiter=',',
                            quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csvwriter.writerow(['Dataset name','Events', 'fragment','notes','Generator','mcdbid','time','size'])
                i=0
                for M, tanb in params_ggH:
                    tmp_fragment=""
                    #print(gridpacks_dict[year][i])
                    #print(dataset_names[year][i])
                    #version = MadgraphVersion.search(path).group(0)
                    version="V2"
                    dataset_name = dataset_names[year][process][i]
                    if year == "2016APV":
                        events = round(tot_events*0.54)
                    elif year == "2016":
                        events = round(tot_events*0.46)
                    else:
                        events = tot_events
                    tmp_fragment = LHEproducer.replace('__GRIDPACK__',gridpacks_dict[year][process][i]) + '\n' + process_pythia_map[process][year]
                    final_fragment = tmp_fragment.replace('__EXAMPLE__',example_dict[year][process])
                    note = dataset_name.replace('_',' ')
                    generators="Powheg_" + version + "  Pythia8"
                    mcdb_id = '0'
                    time = '2'
                    size = '105'
                    csvwriter.writerow([dataset_name, events, final_fragment, note, generators, mcdb_id, time, size])
                    i=i+1
                    
        elif process == "A":
            with open('ggF_'+process+'_'+year+'.csv', 'w') as csvfile:
                csvwriter = csv.writer(csvfile, delimiter=',',
                            quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csvwriter.writerow(['Dataset name','Events', 'fragment','notes','Generator','mcdbid','time','size'])
                i=0  
                for M, tanb in params_ggA:
                    tmp_fragment=""
                    #print(gridpacks_dict[year][i])
                    #print(dataset_names[year][i])
                    #version = MadgraphVersion.search(path).group(0)
                    version="V2"
                    dataset_name = dataset_names[year][process][i]
                    if year == "2016APV":
                        events = round(tot_events*0.54)
                    elif year == "2016":
                        events = round(tot_events*0.46)
                    else:
                        events = tot_events
                    tmp_fragment = LHEproducer.replace('__GRIDPACK__',gridpacks_dict[year][process][i]) + '\n' + process_pythia_map[process][year]
                    final_fragment = tmp_fragment.replace('__EXAMPLE__',example_dict[year][process])
                    note = dataset_name.replace('_',' ')
                    generators="Powheg_" + version + "  Pythia8"
                    mcdb_id = '0'
                    time = '1'
                    size = '105'
                    csvwriter.writerow([dataset_name, events, final_fragment, note, generators, mcdb_id, time, size])
                    i=i+1
                    
        elif process == "h":
            with open('ggF_'+'x'+'_'+year+'.csv', 'w') as csvfile:
                csvwriter = csv.writer(csvfile, delimiter=',',
                            quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csvwriter.writerow(['Dataset name','Events', 'fragment','notes','Generator','mcdbid','time','size'])
                i=0                
                tmp_fragment=""
                version="V2"
                dataset_name = dataset_names[year][process][i]
                if year == "2016APV":
                    events = round(tot_events*0.54)
                elif year == "2016":
                    events = round(tot_events*0.46)
                else:
                    events = tot_events
                tmp_fragment = LHEproducer.replace('__GRIDPACK__',gridpacks_dict[year][process][i]) + '\n' + process_pythia_map[process][year]
                final_fragment = tmp_fragment.replace('__EXAMPLE__',example_dict[year][process])
                note = dataset_name.replace('_',' ')
                generators="Powheg_" + version + "  Pythia8"
                mcdb_id = '0'
                time = '2'
                size = '105'
                csvwriter.writerow([dataset_name, events, final_fragment, note, generators, mcdb_id, time, size])
